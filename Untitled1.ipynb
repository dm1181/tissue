# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sympy import *
from sympy import latex
import mpmath as mp
import numpy as np
from sympy.plotting.plot import plot3d
init_printing()

# %%
x, mu, sigma, a = symbols('x, \mu, \sigma, a')

# %%
def p(x, t, mu):
    return sqrt(a/(pi*sigma**2)) * E**(-(a*(x-mu))**2/(sigma**2))

# %%
p(x, t, mu)
# Out:
#                   2           2
#                 -a ⋅(-\mu + x)
#                 ────────────────
#      _________            2
#     ╱    a          \sigma
#    ╱  ─────── ⋅ℯ
#   ╱         2
# ╲╱    \sigma
# ────────────────────────────────
#                √π

# %%
prob = p(x, t, mu) - p(x, t, -mu)

# %%
prob
# Out:
#                     2          2                      2           2
#                   -a ⋅(\mu + x)                     -a ⋅(-\mu + x)
#                   ───────────────                   ────────────────
#        _________            2            _________            2
#       ╱    a          \sigma            ╱    a          \sigma
#      ╱  ─────── ⋅ℯ                     ╱  ─────── ⋅ℯ
#     ╱         2                       ╱         2
#   ╲╱    \sigma                      ╲╱    \sigma
# - ─────────────────────────────── + ────────────────────────────────
#                  √π                                √π

# %%
simplify(integrate(prob, (x, -oo, oo)))
# Out:
# ⎧
# ⎪                                     0
# ⎪
# ⎪
# ⎪∞
# ⎪⌠
# ⎪⎮  ⎛                    2          2                      2          2 ⎞
# ⎪⎮  ⎜                  -a ⋅(\mu + x)                     -a ⋅(\mu - x)  ⎟
# ⎪⎮  ⎜                  ───────────────                   ───────────────⎟
# ⎨⎮  ⎜       _________            2            _________            2    ⎟
# ⎪⎮  ⎜      ╱    a          \sigma            ╱    a          \sigma     ⎟
# ⎪⎮  ⎜     ╱  ─────── ⋅ℯ                     ╱  ─────── ⋅ℯ               ⎟
# ⎪⎮  ⎜    ╱         2                       ╱         2                  ⎟
# ⎪⎮  ⎜  ╲╱    \sigma                      ╲╱    \sigma                   ⎟
# ⎪⎮  ⎜- ─────────────────────────────── + ───────────────────────────────⎟ dx
# ⎪⎮  ⎝                 √π                                √π              ⎠
# ⎪⌡
# ⎪-∞
# ⎩
#
#     ⎛                             π
# for ⎜│2⋅arg(\sigma) - 2⋅arg(a)│ ≤ ─ ∧ │2⋅arg(\mu) - 4⋅arg(\sigma) + 4⋅arg(a)│
#     ⎝                             2
# ...

# %%
x = symbols('x')
y = Function('y')(x)

# %%
A = symbols('A')

# %%
a, b, c, d, f, g = symbols('a, b, c, d, f, g')

# %%
A_0, kappa, k, alpha, p = symbols('A_0, \kappa, k, \\alpha, p')

# %%
eq = Eq(diff(y, x) + (a*E**(b*x) + c*E**(d*x))*y + f*E**(g*x) )

# %%
eq
# Out:
#    g⋅x   ⎛   b⋅x      d⋅x⎞        d
# f⋅ℯ    + ⎝a⋅ℯ    + c⋅ℯ   ⎠⋅y(x) + ──(y(x)) = 0
#                                   dx

# %%
z = dsolve(eq)

# %%
z
# Out:
#        ⎛     ⎛⎧       ⌠
#        ⎜     ⎜⎪       ⎮          b⋅x     d⋅x
#        ⎜     ⎜⎪       ⎮       a⋅ℯ     c⋅ℯ
#        ⎜     ⎜⎪       ⎮       ──────  ──────
#        ⎜     ⎜⎪       ⎮  g⋅x    b       d
#        ⎜     ⎜⎪    -f⋅⎮ ℯ   ⋅ℯ      ⋅ℯ       dx          for b ≠ 0 ∧ d ≠ 0
#        ⎜     ⎜⎪       ⌡
#        ⎜     ⎜⎪
#        ⎜     ⎜⎪        ⌠
#        ⎜     ⎜⎪        ⎮               b⋅x
#        ⎜     ⎜⎪        ⎮            a⋅ℯ
#        ⎜     ⎜⎪        ⎮            ──────
#        ⎜     ⎜⎪        ⎮  c⋅x  g⋅x    b
#        ⎜     ⎜⎪     -f⋅⎮ ℯ   ⋅ℯ   ⋅ℯ       dx        for b > -∞ ∧ b < ∞ ∧ b ≠
#        ⎜     ⎜⎪        ⌡
# y(x) = ⎜C₁ + ⎜⎨
#        ⎜     ⎜⎪        ⌠
#        ⎜     ⎜⎪        ⎮               d⋅x
#        ⎜     ⎜⎪        ⎮            c⋅ℯ
#        ⎜     ⎜⎪        ⎮            ──────
#        ⎜     ⎜⎪        ⎮  a⋅x  g⋅x    d
#        ⎜     ⎜⎪     -f⋅⎮ ℯ   ⋅ℯ   ⋅ℯ       dx        for d > -∞ ∧ d < ∞ ∧ d ≠
#        ⎜     ⎜⎪        ⌡
#        ⎜     ⎜⎪
# ...

# %%
eq2 = Eq(diff(y, x) + (A_0*a*E**(a*x) + alpha*(b)*E**((b)*x))*y + d*E**((c*x)))

# %%
eq2
# Out:
#    c⋅x   ⎛      a⋅x             b⋅x⎞        d
# d⋅ℯ    + ⎝A₀⋅a⋅ℯ    + \alpha⋅b⋅ℯ   ⎠⋅y(x) + ──(y(x)) = 0
#                                             dx

# %%
z2 = dsolve(eq2)

# %%
z2
# Out:
#        ⎛     ⎛⎧              ⌠
#        ⎜     ⎜⎪              ⎮      a⋅x          b⋅x
#        ⎜     ⎜⎪              ⎮  A₀⋅ℯ     \alpha⋅ℯ     c⋅x
#        ⎜     ⎜⎪           -d⋅⎮ ℯ       ⋅ℯ           ⋅ℯ    dx
#        ⎜     ⎜⎪              ⌡
#        ⎜     ⎜⎪
#        ⎜     ⎜⎪               ⌠
#        ⎜     ⎜⎪               ⎮      a⋅x
#        ⎜     ⎜⎪               ⎮  A₀⋅ℯ     c⋅x  \alpha⋅b⋅x
#        ⎜     ⎜⎪            -d⋅⎮ ℯ       ⋅ℯ   ⋅ℯ           dx              for
#        ⎜     ⎜⎪               ⌡
#        ⎜     ⎜⎪
# y(x) = ⎜C₁ + ⎜⎨               ⌠
#        ⎜     ⎜⎪               ⎮          b⋅x
#        ⎜     ⎜⎪               ⎮  \alpha⋅ℯ     c⋅x  A₀⋅a⋅x
#        ⎜     ⎜⎪            -d⋅⎮ ℯ           ⋅ℯ   ⋅ℯ       dx              for
#        ⎜     ⎜⎪               ⌡
#        ⎜     ⎜⎪
#        ⎜     ⎜⎪   ⎛⎧ c⋅x  A₀⋅a⋅x  \alpha⋅b⋅x                           ⎞
#        ⎜     ⎜⎪   ⎜⎪ℯ   ⋅ℯ      ⋅ℯ                     -(\alpha⋅b + c) ⎟
# ...

# %%
c = symbols('c')

# %%
k, alpha, Omega, t, u, v = symbols('k, \\alpha, \Omega, t, u, v')

# %%
y = A*E**(-(a/b)*E**(b*x)-(c/d)*E**(d*x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c82e15754b4c> in <module>
# ----> 1 y = A*E**(-(a/b)*E**(b*x)-(c/d)*E**(d*x))
#
# NameError: name 'A' is not defined

# %%
z = E**(-I*k*u-alpha*k**2*v)

# %%
z
# Out:
#            2
#  - \alpha⋅k ⋅v - ⅈ⋅k⋅u
# ℯ

# %%
q = inverse_fourier_transform(z, k, x, needeval=True)
# Out:
# ---------------------------------------------------------------------------
# IntegralTransformError                    Traceback (most recent call last)
# <ipython-input-19-085fc18a4de5> in <module>
# ----> 1 q = inverse_fourier_transform(z, k, x, needeval=True)
#
# ~/miniconda3/envs/tissue/lib/python3.7/site-packages/sympy/integrals/transforms.py in inverse_fourier_transform(F, k, x, **hints)
#    1450     mellin_transform, laplace_transform
#    1451     """
# -> 1452     return InverseFourierTransform(F, k, x).doit(**hints)
#    1453
#    1454
#
# ~/miniconda3/envs/tissue/lib/python3.7/site-packages/sympy/integrals/transforms.py in doit(self, **hints)
#     155         if needeval:
#     156             raise IntegralTransformError(
# --> 157                 self.__class__._name, self.function, 'needeval')
#     158
#     159         # TODO handle derivatives etc
#
# IntegralTransformError: Inverse Fourier Transform could not be computed: needeval.

# %%
q
# Out:
#                          ⎛           2  -2⋅\Omega⋅t        -\Omega⋅t      ⎞
#                          ⎜ - \alpha⋅k ⋅ℯ            + ⅈ⋅k⋅ℯ               ⎟
# A⋅InverseFourierTransform⎝ℯ                                         , k, x⎠
